# %%
# base
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Важная настройка для корректной настройки pipeline!
import sklearn
sklearn.set_config(transform_output="pandas")

# Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.base import BaseEstimator, TransformerMixin

# Preprocessing
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA
from sklearn.preprocessing import OneHotEncoder, StandardScaler, RobustScaler, MinMaxScaler, OrdinalEncoder, TargetEncoder
from sklearn.model_selection import GridSearchCV, KFold

# for model learning
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score

#models
from sklearn.neighbors import KNeighborsClassifier, RadiusNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, BaggingClassifier
from catboost import CatBoostRegressor

# Metrics
from sklearn.metrics import accuracy_score


# tunning hyperparamters model
import optuna

# %%
df = pd.read_csv('/home/hopelessdreamer/ds_bootcamp/projects/house_prices/train.csv')

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.columns.get_loc('MSSubClass')
# Out:
# 1

# %%
df.columns.get_loc('TotalBsmtSF')
# Out:
# 38

# %%
fh=df.iloc[:, 1:39]

# %%
fh
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0     7917   Pave   NaN      Reg
# 1456          20       RL         85.0    13175   Pave   NaN      Reg
# 1457          70       RL         66.0     9042   Pave   NaN      Reg
# 1458          20       RL         68.0     9717   Pave   NaN      Reg
# 1459          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... Foundation BsmtQual BsmtCond  \
# ...

# %%
fh.dtypes
# Out:
# MSSubClass        int64
# MSZoning         object
# LotFrontage     float64
# LotArea           int64
# Street           object
# Alley            object
# LotShape         object
# LandContour      object
# Utilities        object
# LotConfig        object
# LandSlope        object
# Neighborhood     object
# Condition1       object
# Condition2       object
# BldgType         object
# HouseStyle       object
# OverallQual       int64
# OverallCond       int64
# YearBuilt         int64
# YearRemodAdd      int64
# RoofStyle        object
# RoofMatl         object
# Exterior1st      object
# Exterior2nd      object
# MasVnrType       object
# MasVnrArea      float64
# ExterQual        object
# ExterCond        object
# Foundation       object
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinSF1        int64
# BsmtFinType2     object
# BsmtFinSF2        int64
# BsmtUnfSF         int64
# TotalBsmtSF       int64
# ...

# %%
types_nans=pd.DataFrame(data={'NaN_count': fh.isna().sum(), 'data_type':fh.dtypes})

# %%
types_nans
# Out:
#               NaN_count data_type
# MSSubClass            0     int64
# MSZoning              0    object
# LotFrontage         259   float64
# LotArea               0     int64
# Street                0    object
# Alley              1369    object
# LotShape              0    object
# LandContour           0    object
# Utilities             0    object
# LotConfig             0    object
# LandSlope             0    object
# Neighborhood          0    object
# Condition1            0    object
# Condition2            0    object
# BldgType              0    object
# HouseStyle            0    object
# OverallQual           0     int64
# OverallCond           0     int64
# YearBuilt             0     int64
# YearRemodAdd          0     int64
# RoofStyle             0    object
# RoofMatl              0    object
# Exterior1st           0    object
# Exterior2nd           0    object
# MasVnrType          872    object
# MasVnrArea            8   float64
# ...

# %%
types_nans.loc[types_nans['NaN_count']>0]
# Out:
#               NaN_count data_type
# LotFrontage         259   float64
# Alley              1369    object
# MasVnrType          872    object
# MasVnrArea            8   float64
# BsmtQual             37    object
# BsmtCond             37    object
# BsmtExposure         38    object
# BsmtFinType1         37    object
# BsmtFinType2         38    object

# %% [markdown]
# Удалить NaN:
# LotFrontage
# MasVnrArea (?)
#
#
# Оставить NaN:
# Alley
# MasVnrType
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2

# %%
fh['LotFrontage']
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
fh['MasVnrArea']
# Out:
# 0       196.0
# 1         0.0
# 2       162.0
# 3         0.0
# 4       350.0
#         ...
# 1455      0.0
# 1456    119.0
# 1457      0.0
# 1458      0.0
# 1459      0.0
# Name: MasVnrArea, Length: 1460, dtype: float64

# %%
fh
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0     7917   Pave   NaN      Reg
# 1456          20       RL         85.0    13175   Pave   NaN      Reg
# 1457          70       RL         66.0     9042   Pave   NaN      Reg
# 1458          20       RL         68.0     9717   Pave   NaN      Reg
# 1459          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... Foundation BsmtQual BsmtCond  \
# ...

# %%
our_imputer = ColumnTransformer(
    transformers = [
        ('num_imputer', SimpleImputer(strategy='mean'), ['LotFrontage','MasVnrArea'])
        ],
    verbose_feature_names_out = False,
    remainder = 'passthrough')

# %%
fh['target'] = df['SalePrice']

# %%
updated = our_imputer.fit_transform(fh)

# %%
pd.DataFrame(data={'NaN_count': updated.isna().sum(), 'data_type':updated.dtypes})
# Out:
#               NaN_count data_type
# LotFrontage           0   float64
# MasVnrArea            0   float64
# MSSubClass            0     int64
# MSZoning              0    object
# LotArea               0     int64
# Street                0    object
# Alley              1369    object
# LotShape              0    object
# LandContour           0    object
# Utilities             0    object
# LotConfig             0    object
# LandSlope             0    object
# Neighborhood          0    object
# Condition1            0    object
# Condition2            0    object
# BldgType              0    object
# HouseStyle            0    object
# OverallQual           0     int64
# OverallCond           0     int64
# YearBuilt             0     int64
# YearRemodAdd          0     int64
# RoofStyle             0    object
# RoofMatl              0    object
# Exterior1st           0    object
# Exterior2nd           0    object
# MasVnrType          872    object
# ...

# %%
preprocessor = Pipeline(
    [
        ('imputer', our_imputer),
        ('encoder', our_encoder),
        ('scaler', our_scaler)
    ]
)

# %%
fh.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'target'],
#       dtype='object')

# %%
our_encoder = ColumnTransformer(
    [
        ('ordinal_encoding', OrdinalEncoder(), ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
       'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
       'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
       'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
       'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'])
    ],
    verbose_feature_names_out = False,
    remainder = 'passthrough' 
)

# %%
updated = our_encoder.fit_transform(updated)

# %%
updated
# Out:
#       MSZoning  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 0          3.0     1.0    NaN       3.0          3.0        0.0        4.0
# 1          3.0     1.0    NaN       3.0          3.0        0.0        2.0
# 2          3.0     1.0    NaN       0.0          3.0        0.0        4.0
# 3          3.0     1.0    NaN       0.0          3.0        0.0        0.0
# 4          3.0     1.0    NaN       0.0          3.0        0.0        2.0
# ...        ...     ...    ...       ...          ...        ...        ...
# 1455       3.0     1.0    NaN       3.0          3.0        0.0        4.0
# 1456       3.0     1.0    NaN       3.0          3.0        0.0        4.0
# 1457       3.0     1.0    NaN       3.0          3.0        0.0        4.0
# 1458       3.0     1.0    NaN       3.0          3.0        0.0        4.0
# 1459       3.0     1.0    NaN       3.0          3.0        0.0        4.0
#
# ...

# %%
pd.DataFrame(data={'NaN_count': updated.isna().sum(), 'data_type':updated.dtypes})
# Out:
#               NaN_count data_type
# MSZoning              0   float64
# Street                0   float64
# Alley              1369   float64
# LotShape              0   float64
# LandContour           0   float64
# Utilities             0   float64
# LotConfig             0   float64
# LandSlope             0   float64
# Neighborhood          0   float64
# Condition1            0   float64
# Condition2            0   float64
# BldgType              0   float64
# HouseStyle            0   float64
# RoofStyle             0   float64
# RoofMatl              0   float64
# Exterior1st           0   float64
# Exterior2nd           0   float64
# MasVnrType          872   float64
# ExterQual             0   float64
# ExterCond             0   float64
# Foundation            0   float64
# BsmtQual             37   float64
# BsmtCond             37   float64
# BsmtExposure         38   float64
# BsmtFinType1         37   float64
# BsmtFinType2         38   float64
# ...

# %%
our_scaler = ColumnTransformer(
    [ 
                ('scaling_num_columns', StandardScaler(), updated.columns.difference(['target']))
    ],
    verbose_feature_names_out = False,
    remainder = 'passthrough' 
)

# %%
updated = our_scaler.fit_transform(updated)

# %%
updated
# Out:
#       Alley  BldgType  BsmtCond  BsmtExposure  BsmtFinSF1  BsmtFinSF2  \
# 0       NaN -0.411691  0.284971      0.640654    0.575425   -0.288653
# 1       NaN -0.411691  0.284971     -1.102906    1.171992   -0.288653
# 2       NaN -0.411691  0.284971     -0.231126    0.092907   -0.288653
# 3       NaN -0.411691 -2.752585      0.640654   -0.499274   -0.288653
# 4       NaN -0.411691  0.284971     -1.974687    0.463568   -0.288653
# ...     ...       ...       ...           ...         ...         ...
# 1455    NaN -0.411691  0.284971      0.640654   -0.973018   -0.288653
# 1456    NaN -0.411691  0.284971      0.640654    0.759659    0.722112
# 1457    NaN -0.411691 -2.752585      0.640654   -0.369871   -0.288653
# 1458    NaN -0.411691  0.284971     -0.231126   -0.865548    6.092188
# 1459    NaN -0.411691  0.284971      0.640654    0.847389    1.509640
#
#       BsmtFinType1  BsmtFinType2  BsmtQual  BsmtUnfSF  ...  OverallCond  \
# ...
